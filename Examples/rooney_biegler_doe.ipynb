# %%
from pyomo.contrib.parmest.examples.rooney_biegler.doe_example import run_rooney_biegler_doe

# %%
run_rooney_biegler_doe(optimize_experiment_A=True)
# Out:
# {'experiment': <pyomo.contrib.parmest.examples.rooney_biegler.rooney_biegler.RooneyBieglerExperiment at 0x12fe8a890>,
#  'results_dict': {},
#  'optimization': {'A': {'Solver Status': <SolverStatus.ok: 'ok'>,
#    'Termination Condition': <TerminationCondition.optimal: 'optimal'>,
#    'Termination Message': 'Ipopt 3.13.2\\x3a Optimal Solution Found',
#    'FIM': [[np.float64(467.52206158217825), np.float64(3510.76423924348)],
#     [np.float64(3510.76423924348), np.float64(42030.60675340917)]],
#    'Sensitivity Matrix': [[np.float64(0.9932619029355911),
#      np.float64(1.010714268901561)]],
#    'Experiment Design': [9.999955457176451],
#    'Experiment Design Names': ['hour'],
#    'Experiment Outputs': [14.913827472578802],
#    'Experiment Output Names': ['y'],
#    'Unknown Parameters': [15.014999999999999, 0.5],
#    'Unknown Parameter Names': ['asymptote', 'rate_constant'],
#    'Measurement Error': [14.913827472578802],
#    'Measurement Error Names': ['y'],
# ...

# %%
run_rooney_biegler_doe(optimize_experiment_A=True)["optimization"]["A"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 run_rooney_biegler_doe(optimize_experiment_A=True)["optimization"]["A"]
#
# TypeError: run_rooney_biegler_doe() got an unexpected keyword argument 'optimize_experiment_A'
